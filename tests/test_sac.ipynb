# %%
import torch
import torch.nn as nn

# %%
import pybullet_envs
import gym
import numpy as np
from gym import wrappers
from soft_actor_critic import SoftActorCritic

# %%
env = gym.make('InvertedPendulumBulletEnv-v0')
print(env.action_space, env.observation_space.shape)
env.reset()
# Out:
# Box(-1.0, 1.0, (1,), float32) (5,)
# argv[0]=
# argv[0]=
# pybullet build time: Nov 28 2023 23:48:36
# array([ 0.        ,  0.        ,  0.99622394, -0.08682091,  0.        ])

# %%
sac = SoftActorCritic(env.observation_space.shape[0], action_dim=env.action_space.shape[0], hidden_size=64)

# %%
best_score = env.reward_range[0]
score_history = []
load_checkpoint = False

# %%
n_episodes = 100
max_size = 10_000
batch_size = 64
learning_freq = 32

# %%
from replay_buffer import ReplayBuffer

replay_buffer = ReplayBuffer(max_size)

# %%
def play_and_record(env, agent, buffer):
    state = env.reset()
    done = False
    score = 0
    while not done:
        action = sac.choose_action(state)
        next_state, reward, done, _ = env.step(action)
        score += reward
        buffer.add(state, action, reward, next_state, done)


        if len(buffer) > batch_size:
            batch = replay_buffer.sample(batch_size)
            sac.learning_step(batch)
            
        state = next_state
    
    return score

# %%
n_episodes = 100_000

# %%
env.reset()
env.render()
# Out:
# array([], dtype=float64)

# %%
from tqdm import tqdm
from utils import plot_learning_curve
import matplotlib.pyplot as plt

for i in tqdm(range(250)):
    score = play_and_record(env, sac, replay_buffer)
    # if len(replay_buffer) >= batch_size:
    #     batch = replay_buffer.sample(batch_size)
    #     sac.learning_step(batch)
    #     sac.update_network_parameters()
    sac.update_network_parameters()
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])
    if avg_score > best_score:
        best_score = avg_score
    if i % 10 == 0 and i > 0:
        print(f"iteration {i} score {score:.3f} avg_score {avg_score:.3f}")
        plot_learning_curve(len(score_history), score_history, running = True) 
        plt.show()

    if avg_score > 900:
        break
# Out:
#  33%|███▎      | 83/250 [24:25<6:40:47, 144.00s/it]

# %%
for i in tqdm(range(250)):
    score = play_and_record(env, sac, replay_buffer)
    batch = replay_buffer.sample(batch_size)
    sac.learning_step(batch)
    sac.update_network_parameters()
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])
    if avg_score > best_score:
        best_score = avg_score
        # sac.save_checkpoint()
    # if i % 250 == 0 and i > 0:
    print(f"iteration {i} score {score:.3f} avg_score {avg_score:.3f}")
    plot_learning_curve(i + 1, score_history)
# Out:
#   0%|          | 0/250 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 for i in tqdm(range(250)):
# ----> 2     score = play_and_record(env, sac, replay_buffer)
#       3     batch = replay_buffer.sample(batch_size)
#       4     sac.learning_step(batch)
#
# Cell In[16], line 14, in play_and_record(env, agent, buffer)
#      12 if len(buffer) > batch_size:
#      13     batch = replay_buffer.sample(batch_size)
# ---> 14     sac.learning_step(batch)
#      15     sac.update_network_parameters()
#      17 state = next_state
#
# File ~/Desktop/Study/Diploma/Actual_version/HindSightExperienceReplay/HindsightExperienceReplay/soft_actor_critic.py:163, in SoftActorCritic.learning_step(self, batch)
#     160 self.__optimize(self.critic2, self.optimizer_critic2, critic2_loss)
#     162 actor_loss = self.__compute_actor_loss(states)
# --> 163 self.__optimize(self.actor, self.optimizer_actor, actor_loss)
#
# File ~/Desktop/Study/Diploma/Actual_version/HindSightExperienceReplay/HindsightExperienceReplay/soft_actor_critic.py:141, in SoftActorCritic.__optimize(self, model, optimizer, loss)
#     139 loss = loss.mean()
#     140 optimizer.zero_grad()
# --> 141 loss.backward(retain_graph=True)
#     142 grad_norm = nn.utils.clip_grad_norm_(model.parameters(), self.max_grad_norm)
#     143 optimizer.step()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
plot_learning_curve(len(score_history), score_history)
