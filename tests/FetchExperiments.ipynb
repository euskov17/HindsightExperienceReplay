# %%
from runner import Runner, MultipleRunner
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
configs = []

n_epochs = 30
general_config =  {'env_name' :'FetchPush-v2',
                    'hidden_size' : 128,
                    'batch_size' : 256, 
                    # 'one_goal' : True
                    }

# %%
# DDPG config with HER
ddpg_her = {'name': "DDPG with HER"}
ddpg_her.update(general_config)
configs.append(ddpg_her)

# DDPG config without HER
# ddpg = {'name': "DDPG+HER", 'using_her': False}
# ddpg.update(general_config)
# configs.append(ddpg)

# Soft-Actor Critic with HER
# sac_her = {'name': "Soft-Actor-Critic with HER", 
# 'agent_name' : 'SAC'}
# sac_her.update(general_config)
# configs.append(sac_her)

# Soft-Actor Critic without HER
# sac = {'name': "Soft-Actor-Critic",  
# 'using_her': False, 'agent_name' : 'SAC'}
# sac.update(general_config)
# configs.append(sac_her)

# %%
m_runner = MultipleRunner(configs)

# %%
for _ in range(n_epochs):
    m_runner.run_epoch()
    m_runner.run_tests(n_tests=20)
    m_runner.plot()
    plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# ...
