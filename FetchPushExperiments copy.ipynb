# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm
from models.soft_actor_critic import SoftActorCritic
from models.ddpg import DDPG
# from rl_models_.her import HindsightExperienceReplay
# from her2 import Player
# from rl_models.her import HindsightExperienceReplay
from rl_models.her_player import Player
from rl_models.replay_buffer import ReplayBuffer
from rl_models.utils import plot_learning_curve

# %%
env_name = 'FetchPush-v2'
max_episode_steps = 50
env = gym.make(env_name, max_episode_steps=max_episode_steps)

env.action_space, env.observation_space
# Out:
# (Box(-1.0, 1.0, (4,), float32),
#  Dict('achieved_goal': Box(-inf, inf, (3,), float64), 'desired_goal': Box(-inf, inf, (3,), float64), 'observation': Box(-inf, inf, (25,), float64)))

# %%
state_dim = env.observation_space['observation'].shape[0]
goal_dim = env.observation_space['desired_goal'].shape[0]
actions_dim = env.action_space.shape[0]
state_dim, actions_dim
# Out:
# (25, 4)

# %%
epochs = 50
epoch_iters = 50
success_history = []
batch_size = 256
gamma = .98

# %%
desired_goal = env.reset()[0]['desired_goal']

# %%
# env2 = gym.make(env_name, max_episode_steps=max_episode_steps)
agent = DDPG(state_dim + goal_dim, actions_dim, 
             hidden_size=256, lr=1e-3,
              tau=0.05, gamma=gamma, clip_bounds=(-1.0/ (1.0 - gamma), 0.0))
replay_buffer = ReplayBuffer(int(1e6))
player = Player(env, agent, replay_buffer)

# %%
# agent2 = SoftActorCritic(state_dim + goal_dim, actions_dim, 
#                          hidden_size=128, lr=1e-3,
#               tau=0.05, gamma=gamma)
# replay_buffer2 = ReplayBuffer(int(1e6))
# player2 = Player(env2, agent2, replay_buffer2)

# %%
# env2 = gym.make(env_name, max_episode_steps=max_episode_steps)
# agent2 = SoftActorCritic(state_dim + goal_dim, actions_dim, hidden_size=256, 
#                          lr=1e-3, tau=0.05, gamma=gamma)
# replay_buffer2 = ReplayBuffer(1000000)
# her2 = HindsightExperienceReplay(env2, agent2, replay_buffer2, 
#                                 batch_size=batch_size, max_steps=max_episode_steps)

# %%
# env3 = gym.make(env_name, max_episode_steps=max_episode_steps)
# agent3 = SoftActorCritic(state_dim + goal_dim, actions_dim, hidden_size=64, 
#                          lr=1e-3, tau=0.95, gamma=gamma)
# replay_buffer3 = ReplayBuffer(1000000)
# her3 = HindsightExperienceReplay(env3, agent3, replay_buffer3, 
#                                 batch_size=batch_size, max_steps=max_episode_steps,
#                                 one_goal_task=desired_goal)

# %%
# her2.play_and_learn()

# %%
success_history2 = []
success_history3 = []

# %%
epsilon = .3
for epoch in range(epochs):
    # score_history = []
    score_history2 = []
    score_history3 = []


    for iter in tqdm(range(epoch_iters)):
        # for _ in range(8):
        score, success = player.play_and_record(epsilon=epsilon, num_episodes=16)
        batch_size = 1024
        player.update_agent(batch_size=batch_size)
        # player.update_network_parameters()
        # score_history.append(float(success))

        # score, success = player2.play_and_record(epsilon=epsilon)
        # player2.update_agent()
        # score_history2.append(float(success))

        # score, success = her2.play_and_learn(num_episodes=16)
        # score_history2.append(float(success))

        # score, success = her3.play_and_learn(num_episodes=16, her=False)
        # score_history3.append(float(success))
    # if epsilon > 0:
    #     epsilon -= 0.005

    # score, success_rate = player.play_and_record(epsilon=epsilon, train=False)
    score, success_rate = player.play_test(n_tests=100)
    # success_rate = np.mean(score_history)
    success_history.append(success_rate)
    plot_learning_curve(success_history, name="DDPG + HER", title="FetchPush success rate") 
    print(score, success_rate)
    # success_rate2 = np.mean(score_history2)
    # success_history2.append(success_rate2)
    # plot_learning_curve(len(success_history2), success_history2, name="Soft-Actor Critic + HER") 

    # success_rate3 = np.mean(score_history3)
    # success_history3.append(success_rate3)
    # plot_learning_curve(len(success_history3), success_history3, name="Soft-Actor Critic without HER", running=True) 

    print(f"Epoch {len(success_history)}")
    print(f"DDPG with HER       success rate = {success_rate}")
    # print(f"Soft-Actor Critic with HER      success rate = {success_rate2}")
    # print(f"Soft-Actor Critic without HER       success rate = {success_rate3}")
    plt.show()
# Out:
# -45.5 0.09
# Epoch 8
# DDPG with HER       success rate = 0.09
#  54%|█████▍    | 27/50 [02:25<02:03,  5.39s/it]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_54776/2674031012.py", line 10, in <module>
#     score, success = player.play_and_record(epsilon=epsilon, num_episodes=16)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/Desktop/Study/Diploma/Actual_version/HindSightExperienceReplay/HindsightExperienceReplay/rl_models/her_player.py", line 69, in play_and_record
#   File "/home/evgeny/Desktop/Study/Diploma/Actual_version/HindSightExperienceReplay/HindsightExperienceReplay/rl_models/her_player.py", line 36, in play_episode
#     next_state, reward, done, _, info = self.env.step(action.numpy())
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/time_limit.py", line 57, in step
#     observation, reward, terminated, truncated, info = self.env.step(action)
#                                                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py", line 56, in step
#     return self.env.step(action)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py", line 51, in step
#     return self.env.step(action)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium_robotics/envs/robot_env.py", line 141, in step
#     obs = self._get_obs()
#           ^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/fetch_env.py", line 118, in _get_obs
#     ) = self.generate_mujoco_observations()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/fetch_env.py", line 321, in generate_mujoco_observations
#     robot_qpos, robot_qvel = self._utils.robot_get_obs(
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium_robotics/utils/mujoco_utils.py", line 28, in robot_get_obs
#     np.squeeze(np.array([get_joint_qpos(model, data, name) for name in names])),
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium_robotics/utils/mujoco_utils.py", line 28, in <listcomp>
#     np.squeeze(np.array([get_joint_qpos(model, data, name) for name in names])),
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/gymnasium_robotics/utils/mujoco_utils.py", line 195, in get_joint_qpos
#     return data.qpos[start_idx:end_idx].copy()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/home/evgeny/anaconda3/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
